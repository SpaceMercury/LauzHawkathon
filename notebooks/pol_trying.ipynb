# %%
import pandas as pd


df = pd.read_csv('../clean_data/BRISTOR_Zegoland_all_%.csv')
# Ensure your dataset is in a DataFrame `df`
df['Date'] = pd.to_datetime(df['Date'])  # Convert to datetime if not already
df = df.sort_values(by='Date')  # Ensure sorted order
df.set_index('Date', inplace=True)  # Set 'Date' as the index
time_series = df['Value']  # Select the target column

# %%
import matplotlib.pyplot as plt

time_series.plot(title='Value Time Series', figsize=(10, 6))
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(time_series)
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] > 0.05:
    print("Time series is non-stationary. Differencing required.")
else:
    print("Time series is stationary.")
    
    
    
## NOT STATIONARY (expected)
# Out:
# ADF Statistic: -0.8989615148419368
# p-value: 0.7883142133600705
# Time series is non-stationary. Differencing required.
